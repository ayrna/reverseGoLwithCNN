# %%
from utils.check_leakage import check_leakage

seeds      = [221, 502, 700, 1204, 3340, 4501, 6054, 6621, 8421, 15678, 19302, 38475, 77293, 91827, 99100]
deltas     = [1]
shapes     = [(15, 15)]
model_names = ["Classic", "DiffGoL", "Annealed"]

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[0],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_221
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_221/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,179 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,637 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,986 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          5  ( 0.03 %)
#   Tableros leakeados en Validation   :          0  ( 0.00 %)
#   Tableros leakeados (train o val)   :          8  ( 0.05 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[1],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_502
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_502/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,208 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,673 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,993 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          6  ( 0.04 %)
#   Tableros leakeados en Validation   :          3  ( 0.02 %)
#   Tableros leakeados (train o val)   :          7  ( 0.05 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[2],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_700
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_700/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,646,298 hashes únicos  |  1,824,000 tableros  |  38 fichero(s)
# [2/3] Indexando Validation...
#       911,682 hashes únicos  |  456,000 tableros  |  38 fichero(s)
# [3/3] Indexando Test...
#       29,988 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          1  ( 0.01 %)
#   Tableros leakeados en Validation   :          1  ( 0.01 %)
#   Tableros leakeados (train o val)   :          3  ( 0.02 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[3],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_1204
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_1204/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,218 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,676 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,994 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          3  ( 0.02 %)
#   Tableros leakeados en Validation   :          0  ( 0.00 %)
#   Tableros leakeados (train o val)   :          5  ( 0.03 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[4],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_3340
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_3340/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,193 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,670 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,993 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          5  ( 0.03 %)
#   Tableros leakeados en Validation   :          1  ( 0.01 %)
#   Tableros leakeados (train o val)   :          7  ( 0.05 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[5],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_4501
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_4501/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,150 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,665 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,992 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          7  ( 0.05 %)
#   Tableros leakeados en Validation   :          3  ( 0.02 %)
#   Tableros leakeados (train o val)   :          8  ( 0.05 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[6],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_6054
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_6054/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,190 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,656 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,994 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          5  ( 0.03 %)
#   Tableros leakeados en Validation   :          1  ( 0.01 %)
#   Tableros leakeados (train o val)   :          8  ( 0.05 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[7],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_6621
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_6621/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,166 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,635 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,994 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          5  ( 0.03 %)
#   Tableros leakeados en Validation   :          0  ( 0.00 %)
#   Tableros leakeados (train o val)   :          6  ( 0.04 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[8],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_8421
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_8421/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,100 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,654 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,996 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          2  ( 0.01 %)
#   Tableros leakeados en Validation   :          1  ( 0.01 %)
#   Tableros leakeados (train o val)   :          2  ( 0.01 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[9],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_15678
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_15678/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,646,151 hashes únicos  |  1,824,000 tableros  |  38 fichero(s)
# [2/3] Indexando Validation...
#       911,683 hashes únicos  |  456,000 tableros  |  38 fichero(s)
# [3/3] Indexando Test...
#       29,992 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          4  ( 0.03 %)
#   Tableros leakeados en Validation   :          2  ( 0.01 %)
#   Tableros leakeados (train o val)   :          7  ( 0.05 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[10],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_19302
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_19302/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,646,223 hashes únicos  |  1,824,000 tableros  |  38 fichero(s)
# [2/3] Indexando Validation...
#       911,677 hashes únicos  |  456,000 tableros  |  38 fichero(s)
# [3/3] Indexando Test...
#       29,992 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          3  ( 0.02 %)
#   Tableros leakeados en Validation   :          0  ( 0.00 %)
#   Tableros leakeados (train o val)   :          5  ( 0.03 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[11],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_38475
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_38475/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,183 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,684 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,995 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          6  ( 0.04 %)
#   Tableros leakeados en Validation   :          0  ( 0.00 %)
#   Tableros leakeados (train o val)   :          7  ( 0.05 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[12],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_77293
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_77293/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...
#       3,742,210 hashes únicos  |  1,872,000 tableros  |  39 fichero(s)
# [2/3] Indexando Validation...
#       935,683 hashes únicos  |  468,000 tableros  |  39 fichero(s)
# [3/3] Indexando Test...
#       29,994 hashes únicos  |  15,000 tableros  |  1 fichero(s)
#
# ─────────────────────────────────────────────────────────────────
#   RESUMEN DE DATA LEAKAGE  (comparando: both)
# ─────────────────────────────────────────────────────────────────
#   Tableros en Test                  :     15,000
#   Tableros leakeados en Train        :          3  ( 0.02 %)
#   Tableros leakeados en Validation   :          3  ( 0.02 %)
#   Tableros leakeados (train o val)   :          7  ( 0.05 %)
# ...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[13],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
# Out:
# ═════════════════════════════════════════════════════════════════
#   Experimento : 15x15_1_91827
#   Modelo      : Classic
#   Comparando  : tableros 'both'
#   Base path   : Data/15x15_1_91827/ConwayStates
# ═════════════════════════════════════════════════════════════════
#
# [1/3] Indexando Train...

# %%
results = check_leakage(
                    parent_folder = "./Data",
                    shape         = "15x15",
                    delta         = 1,
                    seed          = seeds[14],
                    model_name    = 'Classic',
                    check         = "both",
                    verbose       = True,
                )
